# %%
import pandas as pd
import os

# Dossier de sortie
output_folder = "../Shets"

# Créer le dossier s'il n'existe pas
os.makedirs(output_folder, exist_ok=True)

xls = pd.ExcelFile("../data/dataSet.xlsx")

for sheet in xls.sheet_names:
    df = pd.read_excel(xls, sheet_name=sheet)
    df.to_csv(f"{output_folder}/{sheet}.csv", index=False, encoding="utf-8")

print("Conversion terminée ✅")
# Out:
# Conversion terminée ✅

# %%
import pandas as pd
import numpy as np

data = pd.read_csv("../Shets/Table 5. Monday.csv")
data.shape
# Out:
# (440, 59)
