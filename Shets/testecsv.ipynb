# %%
import pandas as pd

xls = pd.ExcelFile("dataSet.xlsx")

for sheet in xls.sheet_names:
    df = pd.read_excel(xls, sheet_name=sheet)
    df.to_csv(f"{sheet}.csv", index=False, encoding="utf-8")

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('Table 5. Monday.csv')
data.shape
# Out:
# (440, 59)
